# %% [markdown]
# # Lab2 Results Notebook\n\nThis notebook records the training artifacts used in `report.pdf`.\n

# %% [markdown]
# ## Key Metrics\n- SFT samples: 300\n- SFT final loss: 0.7964\n- DPO samples: 100 preference pairs\n- DPO final loss: 0.6822\n- DPO check: `DPO normal loss: 0.532641; DPO swapped loss: 1.022753; Batch size: 16`\n

# %% [markdown]
# ## SFT Loss Curve\n![SFT loss](../outputs/sft_loss_curve.png)\n

# %% [markdown]
# ## DPO Loss Curve\n![DPO loss](../outputs/dpo_loss_curve.png)\n

# %% [markdown]
# ## Output Comparison\nSee `../outputs/base_vs_lora.md` for full generated examples.\n
