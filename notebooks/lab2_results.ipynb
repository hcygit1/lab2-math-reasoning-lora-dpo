# %% [markdown]
# # Lab2 实验结果记录
#
# 本 notebook 汇总 `report.pdf` 中使用的训练日志、曲线和验证结果。

# %% [markdown]
# ## 关键指标
# - SFT 训练：全量数据，2 epochs，2700 steps
# - SFT 最终 loss：1.2732
# - DPO 训练：全量偏好对，2 epochs，5398 steps
# - DPO 最终 loss：0.2812
# - DPO 验证：`DPO normal loss: 0.498047; DPO swapped loss: 1.328125; Batch size: 64; Micro batch size: 4`
#
# loss 曲线波动较大是正常现象：日志按 micro batch 记录逐步 loss，单步 loss 受样本难度、回答长度和偏好对差异影响很大，因此报告中同时展示逐步 loss 和滑动平均趋势。

# %% [markdown]
# ## SFT 训练曲线
# ![SFT loss](../outputs/sft_loss_curve.png)

# %% [markdown]
# ## DPO 训练曲线
# ![DPO loss](../outputs/dpo_loss_curve.png)

# %% [markdown]
# ## 输出对比
# 完整文本见 `../outputs/base_vs_lora.md`。
